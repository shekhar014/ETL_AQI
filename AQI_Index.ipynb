# %%
# pandas for handling data
import pandas as pd
# google bigquery library for quering data
from google.cloud import bigquery
# BigQueryHelper for converting query result direct to dataframe
import bq_helper
from bq_helper import BigQueryHelper
# matplotlib for plotting
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')

# import plotly
import plotly
import plotly.offline as py
py.init_notebook_mode(connected=True)
import plotly.tools as tls
import plotly.graph_objs as go
import plotly.tools as tls
import plotly.figure_factory as fig_fact
plotly.tools.set_config_file(world_readable=True, sharing='public')

# %matplotlib inline
# for loading data to mongodb
import pymongo
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)
import os
os.environ["GOOGLE_APPLICATION_CREDENTIALS"]=r"C:\Users\Shekhar\Downloads\TrainingUA2018Shekhar-55c13c58255f.json"
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
patents = bq_helper.BigQueryHelper(active_project="bigquery-public-data",
                                   dataset_name="epa_historical_air_quality")

# View table names under the epa_historical_air_quality data table
bq_assistant = BigQueryHelper("bigquery-public-data", "epa_historical_air_quality")
bq_assistant.list_tables()
# Out:
# ['air_quality_annual_summary',
#  'co_daily_summary',
#  'co_hourly_summary',
#  'hap_daily_summary',
#  'hap_hourly_summary',
#  'lead_daily_summary',
#  'no2_daily_summary',
#  'no2_hourly_summary',
#  'nonoxnoy_daily_summary',
#  'nonoxnoy_hourly_summary',
#  'o3_daily_summary',
#  'o3_hourly_summary',
#  'pm10_daily_summary',
#  'pm10_hourly_summary',
#  'pm25_frm_daily_summary',
#  'pm25_frm_hourly_summary',
#  'pm25_nonfrm_daily_summary',
#  'pm25_nonfrm_hourly_summary',
#  'pm25_speciation_daily_summary',
#  'pm25_speciation_hourly_summary',
#  'pressure_daily_summary',
#  'pressure_hourly_summary',
#  'rh_and_dp_daily_summary',
#  'rh_and_dp_hourly_summary',
#  'so2_daily_summary',
#  'so2_hourly_summary',
#  'temperature_daily_summary',
#  'temperature_hourly_summary',
#  'voc_daily_summary',
#  'voc_hourly_summary',
#  'wind_daily_summary',
#  'wind_hourly_summary']

# %%
# View information on all columns in the co_daily_summary data table
bq_assistant.table_schema("co_daily_summary")
# Out:
#                    name     type      mode  \
# 0            state_code   STRING  NULLABLE
# 1           county_code   STRING  NULLABLE
# 2              site_num   STRING  NULLABLE
# 3        parameter_code  INTEGER  NULLABLE
# 4                   poc  INTEGER  NULLABLE
# 5              latitude    FLOAT  NULLABLE
# 6             longitude    FLOAT  NULLABLE
# 7                 datum   STRING  NULLABLE
# 8        parameter_name   STRING  NULLABLE
# 9       sample_duration   STRING  NULLABLE
# 10   pollutant_standard   STRING  NULLABLE
# 11           date_local     DATE  NULLABLE
# 12     units_of_measure   STRING  NULLABLE
# 13           event_type   STRING  NULLABLE
# 14    observation_count  INTEGER  NULLABLE
# 15  observation_percent    FLOAT  NULLABLE
# 16      arithmetic_mean    FLOAT  NULLABLE
# 17      first_max_value    FLOAT  NULLABLE
# 18       first_max_hour  INTEGER  NULLABLE
# 19                  aqi  INTEGER  NULLABLE
# 20          method_code  INTEGER  NULLABLE
# 21          method_name   STRING  NULLABLE
# 22      local_site_name   STRING  NULLABLE
# 23              address   STRING  NULLABLE
# 24           state_name   STRING  NULLABLE
# 25          county_name   STRING  NULLABLE
# 26            city_name   STRING  NULLABLE
# 27            cbsa_name   STRING  NULLABLE
# 28  date_of_last_change     DATE  NULLABLE
#
#                                           description
# 0   The FIPS code of the state in which the monito...
# 1   The FIPS code of the county in which the monit...
# 2   A unique number within the county identifying ...
# 3   The AQS code corresponding to the parameter me...
# 4   This is the “Parameter Occurrence Code” used t...
# 5   The monitoring site’s angular distance north o...
# 6   The monitoring site’s angular distance east of...
# 7   The Datum associated with the Latitude and Lon...
# 8   The name or description assigned in AQS to the...
# 9   The length of time that air passes through the...
# 10  A description of the ambient air quality stand...
# 11  The calendar date for the summary. All daily s...
# 12  The unit of measure for the parameter. QAD alw...
# 13  Indicates whether data measured during excepti...
# 14  The number of observations (samples) taken dur...
# 15  The percent representing the number of observa...
# 16   The average (arithmetic mean) value for the day.
# 17                     The highest value for the day.
# 18  The hour (on a 24-hour clock) when the highest...
# 19  The Air Quality Index for the day for the poll...
# 20  An internal system code indicating the method ...
# 21  A short description of the processes, equipmen...
# 22  The name of the site (if any) given by the Sta...
# 23  The approximate street address of the monitori...
# 24  The name of the state where the monitoring sit...
# 25  The name of the county where the monitoring si...
# 26  The name of the city where the monitoring site...
# 27  The name of the core bases statistical area (m...
# 28  The date the last time any numeric values in t...

# %%
QUERY = """
    SELECT
        co_daily.state_name,
        avg(co_daily.aqi) as co_avg_aqi,
        avg(no_daily.aqi) as no_avg_aqi
    FROM
      `bigquery-public-data.epa_historical_air_quality.co_daily_summary` AS co_daily
    INNER JOIN `bigquery-public-data.epa_historical_air_quality.no2_daily_summary` AS no_daily
        ON co_daily.state_name = no_daily.state_name
    WHERE
      co_daily.poc = 1
      AND no_daily.poc = 1
      AND EXTRACT(YEAR FROM co_daily.date_local) = 2017
      AND EXTRACT(YEAR FROM no_daily.date_local) = 2017
    GROUP BY co_daily.state_name
        """

bq_assistant = BigQueryHelper("bigquery-public-data", "epa_historical_air_quality")
df_states_gas = bq_assistant.query_to_pandas(QUERY)

# %%
df_states_gas.head()
# Out:
#      state_name  co_avg_aqi  no_avg_aqi
# 0      Oklahoma    4.028633   16.003973
# 1  Rhode Island    5.684062   16.401078
# 2      New York    2.109527   22.824577
# 3     Tennessee    3.725738   20.526027
# 4       Wyoming    1.892903    7.298307

# %%
QUERY = """
    SELECT
        so2_daily.state_name,
        avg(so2_daily.aqi) as so2_avg_aqi
    FROM
      `bigquery-public-data.epa_historical_air_quality.so2_daily_summary` AS so2_daily
    WHERE
      so2_daily.poc = 1
      AND EXTRACT(YEAR FROM so2_daily.date_local) = 2017
    GROUP BY so2_daily.state_name
        """
df_states_gas_so2 = bq_assistant.query_to_pandas(QUERY)
df_states_gas_so2.head()
# Out:
#      state_name  so2_avg_aqi
# 0      Nebraska     5.128915
# 1        Nevada     1.289875
# 2       Vermont     0.200000
# 3  Rhode Island     0.327397
# 4   Mississippi     0.596750

# %%
QUERY = """
    SELECT
        o3_daily.state_name,
        avg(o3_daily.aqi) as o3_avg_aqi
    FROM
      `bigquery-public-data.epa_historical_air_quality.o3_daily_summary` AS o3_daily
    WHERE
      o3_daily.poc = 1
      AND EXTRACT(YEAR FROM o3_daily.date_local) = 2017
    GROUP BY o3_daily.state_name
        """
df_states_gas_o3 = bq_assistant.query_to_pandas(QUERY)
df_states_gas_o3.head()
# Out:
#   state_name  o3_avg_aqi
# 0    Montana   37.153819
# 1     Alaska   26.782881
# 2       Iowa   36.601811
# 3       Ohio   40.216337
# 4      Texas   36.833493

# %%
df_states_gas['o3_avg_aqi'] = df_states_gas['state_name'].map(df_states_gas_o3.set_index('state_name')['o3_avg_aqi'])
df_states_gas['so2_avg_aqi'] = df_states_gas['state_name'].map(df_states_gas_so2.set_index('state_name')['so2_avg_aqi'])

# %%
df_states_gas.head()
# Out:
#      state_name  co_avg_aqi  no_avg_aqi  o3_avg_aqi  so2_avg_aqi
# 0      Oklahoma    4.028633   16.003973   39.244044     4.143517
# 1  Rhode Island    5.684062   16.401078   39.142125     0.327397
# 2      New York    2.109527   22.824577   34.903411     2.245774
# 3     Tennessee    3.725738   20.526027   40.261366    11.788858
# 4       Wyoming    1.892903    7.298307   43.374163     4.167829

# %%
#Insert into MongoDb
#Declare the database
db = client.AQI_db

# %%
data = df_states_gas.to_dict(orient='records')
db.states_aqi.insert_many(data)

# %%
# Verify results:
results = db.states_aqi.find()
for result in results:
    print(result)
# Out:
# {'_id': ObjectId('5bf21989e123ae4b4cbe0db4'), 'state_name': 'Oklahoma', 'co_avg_aqi': 4.028632784538203, 'no_avg_aqi': 16.003972758227835, 'o3_avg_aqi': 39.244044290347865, 'so2_avg_aqi': 4.143517092700956}
# {'_id': ObjectId('5bf21989e123ae4b4cbe0db5'), 'state_name': 'Rhode Island', 'co_avg_aqi': 5.684062059238391, 'no_avg_aqi': 16.40107775211731, 'o3_avg_aqi': 39.14212548015365, 'so2_avg_aqi': 0.32739726027397265}
# {'_id': ObjectId('5bf21989e123ae4b4cbe0db6'), 'state_name': 'New York', 'co_avg_aqi': 2.109526525955382, 'no_avg_aqi': 22.824577025823054, 'o3_avg_aqi': 34.90341134470445, 'so2_avg_aqi': 2.245773524720893}
# {'_id': ObjectId('5bf21989e123ae4b4cbe0db7'), 'state_name': 'Tennessee', 'co_avg_aqi': 3.7257383966244495, 'no_avg_aqi': 20.526027397260552, 'o3_avg_aqi': 40.26136551496114, 'so2_avg_aqi': 11.788857938718664}
# {'_id': ObjectId('5bf21989e123ae4b4cbe0db8'), 'state_name': 'Wyoming', 'co_avg_aqi': 1.8929032258064533, 'no_avg_aqi': 7.2983072916664975, 'o3_avg_aqi': 43.374162975172595, 'so2_avg_aqi': 4.167829457364341}
# {'_id': ObjectId('5bf21989e123ae4b4cbe0db9'), 'state_name': 'Texas', 'co_avg_aqi': 5.1660457690257715, 'no_avg_aqi': 13.464982624965693, 'o3_avg_aqi': 36.83349306431278, 'so2_avg_aqi': 6.223735585217466}
# {'_id': ObjectId('5bf21989e123ae4b4cbe0dba'), 'state_name': 'Colorado', 'co_avg_aqi': 4.962145110409926, 'no_avg_aqi': 17.53462230216012, 'o3_avg_aqi': 46.039751000444646, 'so2_avg_aqi': 2.8323076923076926}
# {'_id': ObjectId('5bf21989e123ae4b4cbe0dbb'), 'state_name': 'Kentucky', 'co_avg_aqi': 3.3610586011342254, 'no_avg_aqi': 13.90455901150404, 'o3_avg_aqi': 38.715338427947586, 'so2_avg_aqi': 3.218297872340424}
# {'_id': ObjectId('5bf21989e123ae4b4cbe0dbc'), 'state_name': 'California', 'co_avg_aqi': 5.424761068853836, 'no_avg_aqi': 17.421248027719493, 'o3_avg_aqi': 46.73344140426716, 'so2_avg_aqi': 1.3216627764810494}
# {'_id': ObjectId('5bf21989e123ae4b4cbe0dbd'), 'state_name': 'Connecticut', 'co_avg_aqi': 4.112403100775186, 'no_avg_aqi': 23.256368118323294, 'o3_avg_aqi': 40.51727447216891, 'so2_avg_aqi': 0.2669491525423729}
# {'_id': ObjectId('5bf21989e123ae4b4cbe0dbe'), 'state_name': 'Utah', 'co_avg_aqi': 5.839268527430304, 'no_avg_aqi': 13.607549430796936, 'o3_avg_aqi': 46.10516381286235, 'so2_avg_aqi': 0.7525423728813561}
# {'_id': ObjectId('5bf21989e123ae4b4cbe0dbf'), 'state_name': 'Maine', 'co_avg_aqi': 2.6605633802817015, 'no_avg_aqi': 12.929945054945096, 'o3_avg_aqi': 34.46190610064664, 'so2_avg_aqi': 1.6342376052385403}
# {'_id': ObjectId('5bf21989e123ae4b4cbe0dc0'), 'state_name': 'Arizona', 'co_avg_aqi': 5.37680209698544, 'no_avg_aqi': 28.311138014527813, 'o3_avg_aqi': 48.191275803295206, 'so2_avg_aqi': 13.294058408862028}
# {'_id': ObjectId('5bf21989e123ae4b4cbe0dc1'), 'state_name': 'Nevada', 'co_avg_aqi': 6.391579900407449, 'no_avg_aqi': 31.16407528641705, 'o3_avg_aqi': 45.60597088576362, 'so2_avg_aqi': 1.2898751733703187}
# {'_id': ObjectId('5bf21989e123ae4b4cbe0dc2'), 'state_name': 'Ohio', 'co_avg_aqi': 3.491071428571301, 'no_avg_aqi': 19.88826815642314, 'o3_avg_aqi': 40.21633738601826, 'so2_avg_aqi': 2.6676943588034345}
# {'_id': ObjectId('5bf21989e123ae4b4cbe0dc3'), 'state_name': 'Pennsylvania', 'co_avg_aqi': 3.7091822495115965, 'no_avg_aqi': 13.55257836198023, 'o3_avg_aqi': 36.092628726287195, 'so2_avg_aqi': 4.440384102427311}
# {'_id': ObjectId('5bf21989e123ae4b4cbe0dc4'), 'state_name': 'Florida', 'co_avg_aqi': 4.63967185527962, 'no_avg_aqi': 14.626097867000322, 'o3_avg_aqi': 34.77280542319597, 'so2_avg_aqi': 2.6928864569083473}
# {'_id': ObjectId('5bf21989e123ae4b4cbe0dc5'), 'state_name': 'Missouri', 'co_avg_aqi': 4.19850885368131, 'no_avg_aqi': 17.991533396047668, 'o3_avg_aqi': 41.32570061517431, 'so2_avg_aqi': 4.502776154295737}
# {'_id': ObjectId('5bf21989e123ae4b4cbe0dc6'), 'state_name': 'Alabama', 'co_avg_aqi': 5.173611111111084, 'no_avg_aqi': 20.30132939438713, 'o3_avg_aqi': 36.609743411927894, 'so2_avg_aqi': 8.085195530726255}
# {'_id': ObjectId('5bf21989e123ae4b4cbe0dc7'), 'state_name': 'Michigan', 'co_avg_aqi': 5.641781874040097, 'no_avg_aqi': 17.547857428916927, 'o3_avg_aqi': 37.68029435813573, 'so2_avg_aqi': 5.752435408725119}
# {'_id': ObjectId('5bf21989e123ae4b4cbe0dc8'), 'state_name': 'Washington', 'co_avg_aqi': 7.029325513196486, 'no_avg_aqi': 21.228020014295314, 'o3_avg_aqi': 36.43596146985374, 'so2_avg_aqi': 12.811391223155928}
# {'_id': ObjectId('5bf21989e123ae4b4cbe0dc9'), 'state_name': 'Massachusetts', 'co_avg_aqi': 3.352256863657465, 'no_avg_aqi': 15.511074197119832, 'o3_avg_aqi': 35.9486867281266, 'so2_avg_aqi': 0.6930147058823526}
# {'_id': ObjectId('5bf21989e123ae4b4cbe0dca'), 'state_name': 'Iowa', 'co_avg_aqi': 2.9626865671641407, 'no_avg_aqi': 9.90650779101731, 'o3_avg_aqi': 36.60181119648738, 'so2_avg_aqi': 2.4801391707741374}
# {'_id': ObjectId('5bf21989e123ae4b4cbe0dcb'), 'state_name': 'Indiana', 'co_avg_aqi': 6.727169597277438, 'no_avg_aqi': 17.904486251808848, 'o3_avg_aqi': 39.22364599350758, 'so2_avg_aqi': 3.7833439019234847}
# {'_id': ObjectId('5bf21989e123ae4b4cbe0dcc'), 'state_name': 'Georgia', 'co_avg_aqi': 7.231671554252062, 'no_avg_aqi': 24.21686746987959, 'o3_avg_aqi': 37.96364423285004, 'so2_avg_aqi': 3.3114663726571116}
# {'_id': ObjectId('5bf21989e123ae4b4cbe0dcd'), 'state_name': 'North Carolina', 'co_avg_aqi': 4.597796143250794, 'no_avg_aqi': 13.448855674918388, 'o3_avg_aqi': 39.781432818643935, 'so2_avg_aqi': 5.930502974580855}
# {'_id': ObjectId('5bf21989e123ae4b4cbe0dce'), 'state_name': 'Wisconsin', 'co_avg_aqi': 2.5746164574616452, 'no_avg_aqi': 18.16097560975623, 'o3_avg_aqi': 38.99190917395278, 'so2_avg_aqi': 2.802507836990596}
# {'_id': ObjectId('5bf21989e123ae4b4cbe0dcf'), 'state_name': 'Illinois', 'co_avg_aqi': 3.110435663627197, 'no_avg_aqi': 25.80922865013798, 'o3_avg_aqi': 39.24044365220839, 'so2_avg_aqi': 7.131174533479688}
# {'_id': ObjectId('5bf21989e123ae4b4cbe0dd0'), 'state_name': 'Minnesota', 'co_avg_aqi': 3.915847424301997, 'no_avg_aqi': 15.044931506849489, 'o3_avg_aqi': 33.43692241564583, 'so2_avg_aqi': 1.6328703703703702}
# {'_id': ObjectId('5bf21989e123ae4b4cbe0dd1'), 'state_name': 'Maryland', 'co_avg_aqi': 2.6123723041997637, 'no_avg_aqi': 18.43000557724587, 'o3_avg_aqi': 41.27115749525615, 'so2_avg_aqi': 7.386262265834077}
# {'_id': ObjectId('5bf21989e123ae4b4cbe0dd2'), 'state_name': 'District Of Columbia', 'co_avg_aqi': 5.355062413314911, 'no_avg_aqi': 21.622161046111685, 'o3_avg_aqi': 33.14351425942961, 'so2_avg_aqi': 1.6465753424657537}
# {'_id': ObjectId('5bf21989e123ae4b4cbe0dd3'), 'state_name': 'Vermont', 'co_avg_aqi': 2.99907063197029, 'no_avg_aqi': 12.69325997249007, 'o3_avg_aqi': 34.33113828786453, 'so2_avg_aqi': 0.20000000000000004}
# {'_id': ObjectId('5bf21989e123ae4b4cbe0dd4'), 'state_name': 'New Jersey', 'co_avg_aqi': 4.72681359044987, 'no_avg_aqi': 21.730051971873653, 'o3_avg_aqi': 35.69669777458717, 'so2_avg_aqi': 0.4949494949494949}
# {'_id': ObjectId('5bf21989e123ae4b4cbe0dd5'), 'state_name': 'North Dakota', 'co_avg_aqi': 2.162534435261724, 'no_avg_aqi': 5.787294563843229, 'o3_avg_aqi': 34.135911288029575, 'so2_avg_aqi': 3.2803003842123633}
# {'_id': ObjectId('5bf21989e123ae4b4cbe0dd6'), 'state_name': 'Puerto Rico', 'co_avg_aqi': 5.824521934758174, 'no_avg_aqi': 23.156441717791626, 'o3_avg_aqi': 14.592814371257484, 'so2_avg_aqi': 4.376513317191284}
# {'_id': ObjectId('5bf21989e123ae4b4cbe0dd7'), 'state_name': 'Montana', 'co_avg_aqi': 1.3965014577259487, 'no_avg_aqi': 2.851393188854575, 'o3_avg_aqi': 37.1538193233345, 'so2_avg_aqi': 5.165562913907286}
# {'_id': ObjectId('5bf21989e123ae4b4cbe0dd8'), 'state_name': 'Oregon', 'co_avg_aqi': 4.306513409961711, 'no_avg_aqi': 17.99170124481268, 'o3_avg_aqi': 37.33415964303418, 'so2_avg_aqi': 0.5028248587570622}
# {'_id': ObjectId('5bf21989e123ae4b4cbe0dd9'), 'state_name': 'South Carolina', 'co_avg_aqi': 3.0226628895184184, 'no_avg_aqi': 10.972194637537177, 'o3_avg_aqi': 36.62814927069518, 'so2_avg_aqi': 0.39454456892352663}
# {'_id': ObjectId('5bf21989e123ae4b4cbe0dda'), 'state_name': 'Virginia', 'co_avg_aqi': 3.858634538152713, 'no_avg_aqi': 15.059648228397286, 'o3_avg_aqi': 38.74209567952326, 'so2_avg_aqi': 7.353335193971529}
# {'_id': ObjectId('5bf21989e123ae4b4cbe0ddb'), 'state_name': 'Louisiana', 'co_avg_aqi': 5.567099567099555, 'no_avg_aqi': 12.989116915422379, 'o3_avg_aqi': 34.782728993738175, 'so2_avg_aqi': 3.8469750889679726}
# {'_id': ObjectId('5bf21989e123ae4b4cbe0ddc'), 'state_name': 'Hawaii', 'co_avg_aqi': 4.801925722145823, 'no_avg_aqi': 8.62460063897764, 'o3_avg_aqi': 27.68987341772152, 'so2_avg_aqi': 50.086247544204305}
# {'_id': ObjectId('5bf21989e123ae4b4cbe0ddd'), 'state_name': 'Alaska', 'co_avg_aqi': 8.135593220339052, 'no_avg_aqi': 21.064425770308173, 'o3_avg_aqi': 26.782881002087684, 'so2_avg_aqi': 15.088154269972453}
# {'_id': ObjectId('5bf21989e123ae4b4cbe0dde'), 'state_name': 'Mississippi', 'co_avg_aqi': 3.967930029154524, 'no_avg_aqi': 9.878453038673998, 'o3_avg_aqi': 35.21138519924099, 'so2_avg_aqi': 0.5967503692762187}
# {'_id': ObjectId('5bf21989e123ae4b4cbe0ddf'), 'state_name': 'Kansas', 'co_avg_aqi': 3.374631268436577, 'no_avg_aqi': 8.794351918899212, 'o3_avg_aqi': 35.553044569993695, 'so2_avg_aqi': 1.3421998562185478}
# {'_id': ObjectId('5bf21989e123ae4b4cbe0de0'), 'state_name': 'New Mexico', 'co_avg_aqi': 3.431318681318705, 'no_avg_aqi': 13.55771065182853, 'o3_avg_aqi': 47.01326530612245, 'so2_avg_aqi': 1.5674116798846427}
# {'_id': ObjectId('5bf21989e123ae4b4cbe0de1'), 'state_name': 'Delaware', 'co_avg_aqi': 3.9458598726114604, 'no_avg_aqi': 20.592696629213624, 'o3_avg_aqi': 37.35121951219514, 'so2_avg_aqi': 0.46969696969696967}

# %%
states = {'AL': 'Alabama',
'AK': 'Alaska',
'AZ':'Arizona',
'AR':'Arkansas',
'CA':'California',
'CO':'Colorado',
'CT':'Connecticut',
'DE':'Delaware',
'FL':'Florida',
'GA':'Georgia',
'HI':'Hawaii',
'ID':'Idaho',
'IL':'Illinois',
'IN':'Indiana',
'IA':'Iowa',
'KS':'Kansas',
'KY':'Kentucky',
'LA':'Louisiana',
'ME':'Maine',
'MD':'Maryland',
'MA':'Massachusetts',
'MI':'Michigan',
'MN':'Minnesota',
'MS':'Mississippi',
'MO':'Missouri',
'MT':'Montana',
'NE':'Nebraska',
'NV':'Nevada',
'NH':'New Hampshire',
'NJ':'New Jersey',
'NM':'New Mexico',
'NY':'New York',
'NC':'North Carolina',
'ND':'North Dakota',
'OH':'Ohio',
'OK':'Oklahoma',
'OR':'Oregon',
'PA':'Pennsylvania',
'RI':'Rhode Island',
'SC':'South Carolina',
'SD':'South Dakota',
'TN':'Tennessee',
'TX':'Texas',
'UT':'Utah',
'VT':'Vermont',
'VA':'Virginia',
'WA':'Washington',
'WV':'West Virginia',
'WI':'Wisconsin',
'WY':'Wyoming'}

# %%
df_states = pd.DataFrame.from_dict(states,orient='index').reset_index()
df_states.columns = ['code', 'code_name']
df_states_gas['state_code'] = df_states_gas['state_name'].map(df_states.set_index('code_name')['code'])

# %%
scl = [[0.0, 'rgb(242,240,247)'],[0.2, 'rgb(218,218,235)'],[0.4, 'rgb(188,189,220)'],[0.6, 'rgb(158,154,200)'],[0.8, 'rgb(117,107,177)'],[1.0, 'rgb(84,39,143)']]


data = [ dict(
        type='choropleth',
        colorscale = scl,
        autocolorscale = False,
        locations = df_states_gas['state_code'],
        z = df_states_gas['o3_avg_aqi'].astype(float),
        locationmode = 'USA-states',
        text =  'Average AQI of NO: ' + df_states_gas['no_avg_aqi'].astype(str) + '<br>' + 'Average AQI of CO: ' + df_states_gas['co_avg_aqi'].astype(str) + '<br>' + 'Average AQI of SO2: ' + df_states_gas['so2_avg_aqi'].astype(str),
        marker = dict(
            line = dict (
                color = 'rgb(255,255,255)',
                width = 2
            ) ),
        colorbar = dict(
            title = "AQI of O3")
        ) ]

layout = dict(
        title = 'The average air quality index of some dangerous element in different US states<br>(Hover for breakdown)',
        geo = dict(
            scope='usa',
            projection=dict( type='albers usa' ),
            showlakes = True,
            lakecolor = 'rgb(255, 255, 255)'),
             )




    
fig = dict( data=data, layout=layout )

py.iplot( fig, filename='d3-cloropleth-map' )
# Out:
# <div id="65f05896-0fab-4716-9414-99acda4b25b0" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("65f05896-0fab-4716-9414-99acda4b25b0", [{"autocolorscale": false, "colorbar": {"title": "AQI of O3"}, "colorscale": [[0.0, "rgb(242,240,247)"], [0.2, "rgb(218,218,235)"], [0.4, "rgb(188,189,220)"], [0.6, "rgb(158,154,200)"], [0.8, "rgb(117,107,177)"], [1.0, "rgb(84,39,143)"]], "locationmode": "USA-states", "locations": ["PA", "MI", "FL", "CA", "AZ", "TX", "KY", "MA", "NJ", "IN", "CO", "WY", "NV", "OH", "NY", "KS", "UT", "ND", "NM", "VA", "WA", "TN", "IL", "CT", "GA", "RI", "NC", "AL", "LA", "MN", "MS", "MO", "IA", "OK", "SC", "MD", null, "DE", "MT", "HI", "VT", "ME", "WI", "AK", "OR", null], "marker": {"line": {"color": "rgb(255,255,255)", "width": 2}}, "text": ["Average AQI of NO: 13.5525783619826<br>Average AQI of CO: 3.7091822495116733<br>Average AQI of SO2: 4.440384102427311", "Average AQI of NO: 17.547857428908397<br>Average AQI of CO: 5.641781874039712<br>Average AQI of SO2: 5.752435408725118", "Average AQI of NO: 14.626097867003715<br>Average AQI of CO: 4.639671855278566<br>Average AQI of SO2: 2.6928864569083473", "Average AQI of NO: 17.421248027734045<br>Average AQI of CO: 5.424761068850034<br>Average AQI of SO2: 1.3216627764810496", "Average AQI of NO: 28.311138014524804<br>Average AQI of CO: 5.376802096985925<br>Average AQI of SO2: 13.294058408862027", "Average AQI of NO: 13.46498262496849<br>Average AQI of CO: 5.166045769026089<br>Average AQI of SO2: 6.223735585217467", "Average AQI of NO: 13.90455901150488<br>Average AQI of CO: 3.361058601134271<br>Average AQI of SO2: 3.2182978723404245", "Average AQI of NO: 15.511074197120035<br>Average AQI of CO: 3.352256863657296<br>Average AQI of SO2: 0.6930147058823526", "Average AQI of NO: 21.730051971872985<br>Average AQI of CO: 4.726813590450097<br>Average AQI of SO2: 0.494949494949495", "Average AQI of NO: 17.904486251809058<br>Average AQI of CO: 6.727169597277205<br>Average AQI of SO2: 3.7833439019234847", "Average AQI of NO: 17.53462230215997<br>Average AQI of CO: 4.962145110410283<br>Average AQI of SO2: 2.8323076923076926", "Average AQI of NO: 7.298307291666231<br>Average AQI of CO: 1.8929032258064782<br>Average AQI of SO2: 4.16782945736434", "Average AQI of NO: 31.164075286415944<br>Average AQI of CO: 6.391579900407627<br>Average AQI of SO2: 1.2898751733703189", "Average AQI of NO: 19.888268156420263<br>Average AQI of CO: 3.491071428571806<br>Average AQI of SO2: 2.667694358803435", "Average AQI of NO: 22.824577025822403<br>Average AQI of CO: 2.109526525955066<br>Average AQI of SO2: 2.2457735247208928", "Average AQI of NO: 8.794351918899102<br>Average AQI of CO: 3.374631268436607<br>Average AQI of SO2: 1.3421998562185478", "Average AQI of NO: 13.607549430796029<br>Average AQI of CO: 5.839268527430115<br>Average AQI of SO2: 0.7525423728813561", "Average AQI of NO: 5.787294563843093<br>Average AQI of CO: 2.1625344352617746<br>Average AQI of SO2: 3.2803003842123633", "Average AQI of NO: 13.557710651827803<br>Average AQI of CO: 3.4313186813187717<br>Average AQI of SO2: 1.5674116798846427", "Average AQI of NO: 15.059648228396103<br>Average AQI of CO: 3.858634538152656<br>Average AQI of SO2: 7.353335193971529", "Average AQI of NO: 21.22802001429532<br>Average AQI of CO: 7.029325513196395<br>Average AQI of SO2: 12.811391223155926", "Average AQI of NO: 20.52602739726071<br>Average AQI of CO: 3.725738396624302<br>Average AQI of SO2: 11.788857938718666", "Average AQI of NO: 25.809228650136976<br>Average AQI of CO: 3.110435663627071<br>Average AQI of SO2: 7.1311745334796885", "Average AQI of NO: 23.25636811832515<br>Average AQI of CO: 4.112403100775002<br>Average AQI of SO2: 0.26694915254237295", "Average AQI of NO: 24.21686746987793<br>Average AQI of CO: 7.231671554252204<br>Average AQI of SO2: 3.3114 ...
